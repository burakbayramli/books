# %% [markdown]
# ![image](Figs/CoverFrontMed.png)
# ![image](Figs/CoverBackMed.png)
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ***
# <p>
# Rubin H. Landau<br>
# Manuel J. Paez<br>
# Cristian C. Bordeianu</p><br><br><br>
#
# ### Computational Physics
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ***
#
# *Rubin H. Landau<br>
# Manuel J. Paez<br>
# Cristian C. Bordeianu*<br><br><br><br><br><br>
#
# ## Computational Physics
#
# ### Problem Solving with Python
#
# #### 3rd completely revised edition
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# # Wiley-VCH<br>
# Verlag GmbH &amp; Co, KGAa
#
# ***
#
#
# ![image](Figs/WileyCopyright.png)
#
# ***
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# To the memory of Cristian C. Bordeianu and his many contributions,  but especially his friendship
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ***

# %% [markdown]
# # Short Table of Contents (with Chapter Links)<br>
#
# [**1 Introduction**](CP01.ipynb)<br>
# [**2 Computing Software Basics**](CP02.ipynb)<br>
# [**3 Errors & Uncertainties in Computations**](CP03.ipynb)<br>
# [**4 Monte Carlo: Randomness, Walks & Decays**](CP04.ipynb)<br>
# [**5 Differentiation & Integration**](CP05.ipynb)<br>
# [**6 Matrix Computing**](CP06.ipynb)<br>
# [**7 Trial-and-Error Searching & Data Fitting**](CP07.ipynb)<br>
# [**8 Solving Differential Equations; Nonlinear Oscillations**](CP08.ipynb)<br>
# [**9 ODE Applications**](CP09.ipynb)<br>
# [**10 High-Performance Hardware & Parallel Computers**](CP10.ipynb)<br>
# [**11 Applied HPC: Optimization, Tuning & GPU Programming**](CP11.ipynb)<br>
# [**12 Fourier Analysis: Signals & Filters**](CP12.ipynb)<br>
# [**13 Wavelet & Principal Components Analyses**](CP13.ipynb)<br>
# [**14 Nonlinear Population Dynamics**](CP14.ipynb)<br>
# [**15 Continuous Nonlinear Dynamics**](CP15.ipynb)<br>
# [**16 Fractals & Statistical Growth Models**](CP16.ipynb)<br>
# [**17 Thermodynamic Simulations & Feynman Path Integrals**](CP17.ipynb)<br>
# [**18 Molecular Dynamics Simulations**](CP18.ipynb)<br>
# [**19 PDE Review & Electrostatics via Finite Differences**](CP19.ipynb)<br>
# [**20 Heat Flow via Time Stepping**](CP20.ipynb)<br>
# [**21 Wave Equations I: Strings & Membranes**](CP21.ipynb)<br>
# [**22 Wave Equations II: Quantum Packets & E-M**](CP22.ipynb)<br>
# [**23 Electrostatics via Finite Elements**](CP23.ipynb)<br>
# [**24 Shock Waves and Solitons**](CP24.ipynb)<br>
# [**25 Fluid Dynamics**](CP25.ipynb)<br>
# [**26 Integral Equations of Quantum Mechanics**](CP26.ipynb)<br>
# [**A Codes, Applets & Animations**](Append.ipynb)<br>
# [**Bibliography**](Biblio.ipynb)

# %% [markdown]
# # Detailed Table of Contents (with Chapter & Section Links)<br>
#
# [**1 Introduction**](CP01.ipynb)<br>
# [1.0 Reading this eBook or Python Notebook](CP01.ipynb#1.0)<br>
# [1.1 Computational Physics & Computational Science](CP01.ipynb#1.1)<br>
# [1.2 This Book’s Subjects](CP01.ipynb#1.2)<br>
# [1.3 This Book’s Codes and Problems](CP01.ipynb#1.3)<br>
#  [1.4 This Book’s Language: The Python Ecosystem](CP01.ipynb#1.4)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[1.4.1 Python Packages (Libraries)](CP01.ipynb#1.4.22)<br>
#  &nbsp;&nbsp;&nbsp;&nbsp;[1.4.2 This Book’s Packages](CP01.ipynb#1.4.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; [1.4.3 The Easy Way: Python Distributions](CP01.ipynb#1.4.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; [1.4.4 Using Python (Jupyter) Notebooks](CP01.ipynb#1.4.4)<br>
# [1.5 Python’s Visualization Tools](CP01.ipynb#1.5)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[1.5.1 Visual (VPython)’s 2-D Plots](CP01.ipynb#1.5.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[1.5.2 Vpython’s Animations](CP01.ipynb#1.5.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[1.5.3 Matplotlib’s 2-D Plots](CP01.ipynb#1.5.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[1.5.4 Matplotlib’s 3-D Surface Plots](CP01.ipynb#1.5.4)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[1.5.5 Matplotlib’s Animations](CP01.ipynb#1.5.5)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[1.5.6 Mayavi’s Visualizations Beyond Plotting](CP01.ipynb#1.5.6)<br>
# [1.6 Plotting Exercises](CP01.ipynb#1.6)<br>
# [1.7 Python’s Algebraic Tools](CP01.ipynb#1.7)<br>
#
# [**2 Computing Software Basics**](CP02.ipynb)<br>
# [2.1 Making Computers Obey](CP02.ipynb#2.1)<br>
# [2.2 Programming Warmup](CP02.ipynb#2.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[2.2.1 Structured & Reproducible Program Design](CP02.ipynb#2.2.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[2.2.2 Shells, Editors and Execution](CP02.ipynb#2.2.2)<br>
# [2.3 Python I/O](CP02.ipynb#2.3)<br>
# [2.4 Computer Number Representations (Theory)](CP02.ipynb#2.4)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[2.4.1 IEEE Floating-Point Numbers](CP02.ipynb#2.4.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[2.4.2 Python and the IEEE 754 Standard](CP02.ipynb#2.4.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[2.4.3 Over & Underflow Exercises](CP02.ipynb#2.4.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[2.4.4 Machine Precision (Model)](CP02.ipynb#2.4.4)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[2.4.5 Experiment: Your Machine’s Precision](CP02.ipynb#2.4.5)<br>
# [2.5 Problem: Summing Series](CP02.ipynb#2.5)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[2.5.1 Numerical Summation (Method)](CP02.ipynb#2.5.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[2.5.2 Implementation and Assessment](CP02.ipynb#2.5.2)<br>
#
# [**3 Errors & Uncertainties in Computations**](CP03.ipynb)<br>
# [3.1 Types of Errors (Theory)](CP03.ipynb#3.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[3.1.1 Model for Disaster: Subtractive Cancellation](CP03.ipynb#3.1.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[3.1.2 Subtractive Cancellation Exercises](CP03.ipynb#3.1.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[3.1.3 Round-off Errors](CP03.ipynb#3.1.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[3.1.4 Round-off Error Accumulation](CP03.ipynb#3.1.4)<br>
# [3.2 Error in Bessel Functions (Problem)](CP03.ipynb#3.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[3.2.1 Numerical Recursion (Method)](CP03.ipynb#3.2.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[3.2.2 Recursion Relations Assessment](CP03.ipynb#3.2.1)<br>
# [3.3 Experimental Error Investigation](CP03.ipynb#3.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[3.3.1 Error Assessment](CP03.ipynb#3.3.1)<br>
#
# [**4 Monte Carlo: Randomness, Walks & Decays**](CP04.ipynb)<br>
# [4.1 Deterministic Randomness](CP04.ipynb#4.1)<br>
# [4.2 Random Sequences (Theory)](CP04.ipynb#4.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[4.2.1 Random-Number Generation (Algorithm)](CP04.ipynb#4.2.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[4.2.2 Implementation: Random Sequences](CP04.ipynb#4.2.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[4.2.3 Assessing Randomness and Uniformity](CP04.ipynb#4.2.3)<br>
# [4.3 RandomWalks (Problem)](CP04.ipynb#4.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[4.3.1 Random-Walk Simulation](CP04.ipynb#4.3.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[4.3.2 Implementation: Random Walk](CP04.ipynb#4.3.2)<br>
# [4.4 Extension: Protein Folding & Self-Avoiding Random Walks](CP04.ipynb#4.4)<br>
# [4.5 Spontaneous Decay (Problem)](CP04.ipynb#4.5)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[4.5.1 Discrete Decay (Model)](CP04.ipynb#4.5.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[4.5.2 Continuous Decay (Model)](CP04.ipynb#4.5.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[4.5.3 Decay Simulation](CP04.ipynb#4.5.3)<br>
# [4.6 Decay Implementation and Visualization](CP04.ipynb#4.6)<br>
#
# [**5 Differentiation & Integration**](CP05.ipynb)<br>
# [5.1 Differentiation](CP05.ipynb#5.1)<br>
# [5.2 Forward Difference (Algorithm)](CP05.ipynb#5.2)<br>
# [5.3 Central Difference (Algorithm)](CP05.ipynb#5.3)<br>
# [5.4 Extrapolated Difference (Algorithm)](CP05.ipynb#5.4)<br>
# [5.5 Error Assessment](CP05.ipynb#5.5)<br>
# [5.6 Second Derivatives (Problem)](CP05.ipynb#5.6)<br>
# [5.6.1 Second-Derivative Assessment](CP05.ipynb#5.6.1)<br>
# [5.7 Integration](CP05.ipynb#5.7)<br>
# [5.8 Quadrature as Box Counting (Math)](CP05.ipynb#5.8)<br>
# [5.9 Algorithm: Trapezoid Rule](CP05.ipynb#5.9)<br>
# [5.10 Algorithm: Simpson’s Rule](CP05.ipynb#5.10)<br>
# [5.11 Integration Error (Assessment)](CP05.ipynb#5.11)<br>
# [5.12 Algorithm: Gaussian Quadrature](CP05.ipynb#5.12)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.12.1 Mapping Integration Points](CP05.ipynb#5.12.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.12.2 Gaussian Points Derivation](CP05.ipynb#5.12.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.12.3 Integration Error Assessment](CP05.ipynb#5.12.3)<br>
# [5.13 Higher-Order Rules (Algorithm)](CP05.ipynb#5.13)<br>
# [5.14 Monte Carlo Integration by Stone Throwing](CP05.ipynb#5.14)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.14.1 Stone Throwing Implementation](CP05.ipynb#5.14.1)<br>
# [5.15 Mean Value Integration (Theory & Math)](CP05.ipynb#5.15)<br>
# [5.16 Integration Exercises](CP05.ipynb#5.16)<br>
# [5.17 Multidimensional Monte Carlo Integration (Problem)](CP05.ipynb#5.17)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.17.1 Multi Dimension Integration Error Assessment](CP05.ipynb#5.17.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.17.2 Implementation: 10-D Monte Carlo Integration](CP05.ipynb#5.17.2)<br>
# [5.18 Integrating Rapidly Varying Functions (Problem)](CP05.ipynb#5.18)<br>
# [5.19 Variance Reduction (Method)](CP05.ipynb#5.19)<br>
# [5.20 Importance Sampling (Method)](CP05.ipynb#5.20)<br>
# [5.21 Von Neumann Rejection (Method)](CP05.ipynb#5.21)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.21.1 Simple Random Gaussian Distribution](CP05.ipynb#5.21.1)<br>
# [5.22 Nonuniform Assessment](CP05.ipynb#5.22)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.22.1 Implementation](CP05.ipynb#5.22.1)<br>
#
# [**6 Matrix Computing**](CP06.ipynb)<br>
# [6.1 Problem 3: N-D Newton-Raphson; Two Masses on a String](CP06.ipynb#6.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.1.1 Theory: Statics](CP06.ipynb#6.1.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.1.2 Algorithm: Multidimensional Searching](CP06.ipynb#6.1.2)<br>
# [6.2 Why Matrix Computing?](CP06.ipynb#6.2)<br>
# [6.3 Classes of Matrix Problems (Maths)](CP06.ipynb#6.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.3.1 Practical Matrix Computing](CP06.ipynb#6.3.1)<br>
# [6.4 Python Lists as Arrays](CP06.ipynb#6.4)<br>
# [6.5 Numerical Python (NumPy) Arrays](CP06.ipynb#6.5)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.5.1 NumPy’s linalg Package](CP06.ipynb#6.5.1)<br>
# [6.6 Exercise: Testing Matrix Programs](CP06.ipynb#6.6)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.6.1 Matrix Solution of the String Problem](CP06.ipynb#6.6.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.6.2 Explorations](CP06.ipynb#6.6.2)<br>
#
# [**7 Trial-and-Error Searching & Data Fitting**](CP07.ipynb)<br>
# [7.1 Problem 1: A Search for Quantum States in a Box](CP07.ipynb#7.1)<br>
# [7.2 Algorithm: Trial-and-Error Roots via Bisection](CP07.ipynb#7.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.2.1 Implementation: Bisection Algorithm](CP07.ipynb#7.2.1)<br>
# [7.3 Improved Algorithm: Newton-Raphson Searching](CP07.ipynb#7.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.3.1 Newton-Raphson with Backtracking](CP07.ipynb#7.3.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.3.2 Implementation: Newton-Raphson Algorithm](CP07.ipynb#7.3.2)<br>
# [7.4 Problem 2: Temperature Dependence of Magnetization](CP07.ipynb#7.4)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.4.1 Searching Exercise](CP07.ipynb#7.4.1)<br>
# [7.5 Problem 3: Fitting An Experimental Spectrum](CP07.ipynb#7.5)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.5.1 Lagrange Implementation, Assessment](CP07.ipynb#7.5.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.5.2 Cubic Spline Interpolation](CP07.ipynb#7.5.2)<br>
# [7.6 Problem 4:Fitting Exponential Decay](CP07.ipynb#7.6)<br>
# [7.7 Least-Squares Fitting (Theory)](CP07.ipynb#7.7)<br>
# [7.7.1 Theory and Implementation](CP07.ipynb#7.7.1)<br>
# [7.8 Exercises: Fitting Exponential Decay, Heat Flow & Hubble’s Law](CP07.ipynb#7.81)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.8.1 Linear Quadratic Fit](CP07.ipynb#7.8.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.8.2 Problem 5: Nonlinear Fit to a Breit-Wigner](CP07.ipynb#7.8.2)<br>
#
# [**8 Solving Differential Equations; Nonlinear Oscillations**](CP08.ipynb)<br>
# [8.1 Free Nonlinear Oscillations](CP08.ipynb#8.1)<br>
# [8.2 Nonlinear Oscillators (Models) (Math)](CP08.ipynb#8.2)<br>
# [8.3  Types of Differential Equations (Math)](CP08.ipynb#8.3)<br>
# [8.4 Dynamic Form for ODE’s (Theory)](CP08.ipynb#8.4)<br>
# [8.5 ODE Algorithms](CP08.ipynb#8.51)<br>
# [8.5.1 Euler’s Rule ](CP08.ipynb#8.5.1)<br>
# [8.6 Runge-Kutta Rule](CP08.ipynb#8.6)<br>
# [8.7 ABM Predictor-Corrector Rule](CP08.ipynb#8.7)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.7.1 Assessment: rk2 versus rk4 versus rk45](CP08.ipynb#8.7.1)<br>
# [8.8 Solution for Nonlinear Oscillations (Assessment)](CP08.ipynb#8.8)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.8.1 Precision Assessment: Energy Conservation](CP08.ipynb#8.8.1)<br>
# [8.9 Extensions: Nonlinear Resonances, Beats, Friction](CP08.ipynb#8.9)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.9.1 Friction (Model)](CP08.ipynb#8.9.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.9.2 Resonances & Beats: Model, Implementation](CP08.ipynb#8.9.2)<br>
# [8.10 Extension: Time-Dependent Forces](CP08.ipynb#8.10)<br>
#
# [**9 ODE Applications**](CP09.ipynb)<br>
# [9.1 Problem: Quantum Eigenvalues in Arbitrary Potential](CP09.ipynb#9.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[9.1.1 Model: Nucleon in a Box](CP09.ipynb#9.1.1)<br>
# [9.2 Algorithm: Eigenvalues via ODE Solver + Search](CP09.ipynb#9.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[9.2.1 Numerov Algorithm for Schrödinger ODE](CP09.ipynb#9.2.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; [9.2.2 Implementation](CP09.ipynb#9.2.2)<br>
# [9.3 Explorations](CP09.ipynb#9.3)<br>
# [9.4 Problem: Classical Chaotic Scattering](CP09.ipynb#9.4)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[9.4.1 Model and Theory](CP09.ipynb#9.4.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[9.4.2 Implementation](CP09.ipynb#9.4.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[9.4.3 Assessment](CP09.ipynb#9.4.3)<br>
# [9.5 Problem: Balls Falling Out of the Sky](CP09.ipynb#9.5)<br>
# [9.6 Theory: Projectile Motion with Drag](CP09.ipynb#9.6)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[9.6.1 Simultaneous Second-Order ODE’s](CP09.ipynb#9.6.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[9.6.2 Assessment](CP09.ipynb#9.6.2)<br>
# [9.7 Exercises: 2- & 3-Body Planet Orbits & Chaotic Weather](CP09.ipynb#9.7)<br>
#
# [**10 High-Performance Hardware & Parallel Computers**](CP10.ipynb)<br>
# [10.1 High-Performance Computers](CP10.ipynb#10.1)<br>
# [10.2 Memory Hierarchy](CP10.ipynb#10.2)<br>
# [10.3 The Central Processing Unit](CP10.ipynb#10.3)<br>
# [10.4 CPU Design: Reduced Instruction Set Processors](CP10.ipynb#10.4)<br>
# [10.5 CPU Design: Multiple-Core Processors](CP10.ipynb#10.5)<br>
# [10.6 CPU Design: Vector Processors](CP10.ipynb#10.6)<br>
# [10.7 Introduction to Parallel Computing](CP10.ipynb#10.7)<br>
# [10.8 Parallel Semantics (Theory)](CP10.ipynb#10.8)<br>
# [10.9 Distributed Memory Programming](CP10.ipynb#10.9)<br>
# [10.10 Parallel Performance](CP10ipynb#10.10)<br>
# [10.10.1 Communication Overhead](CP10.ipynb#10.10.1)<br>
# [10.11 Parallelization Strategies](CP10.ipynb#10.11)<br>
# [10.12 Practical Aspects of MIMD Message Passing](CP10.ipynb#10.12)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[10.12.1 High-Level View of Message Passing](CP10ipynb#10.12.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[10.12.2 Message Passing Example & Exercise](CP10.ipynb#10.12.2)<br>
# [10.13 Scalability](CP10.ipynb#10.13)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[10.13.1 Scalability Exercises](CP10.ipynb#10.13.1)<br>
# [10.14 Data Parallelism and Domain Decomposition](CP10.ipynb#10.14)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[10.14.1 Domain Decomposition Exercises](CP10.ipynb#10.14.1)<br>
# [10.15 The IBM Blue Gene Supercomputers](CP10.ipynb#10.15.1)<br>
# [10.16 Exascale Computing via Multinode-Multicore-GPU’s](CP10.ipynb#10.16)<br>
#
# [**11 Applied HPC: Optimization, Tuning & GPU Programming**](CP11.ipynb)<br>
# [11.1 General Program Optimization](CP11.ipynb#11.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[11.1.1 Programming for Virtual Memory](CP11.ipynb#11.1.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[11.1.2 Optimization Exercises](CP11.ipynb#11.1.2)<br>
# [11.2 Optimized Matrix Programming with NumPy](CP11.ipynb#11.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[11.2.1 NumPy Optimization Exercises](CP11.ipynb#11.2.1)<br>
# [11.3 Empirical Performance of Hardware](CP11.ipynb#11.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[11.3.1 Racing Python versus Fortran/C](CP11.ipynb#11.3.1)<br>
# [11.4 Programming for the Data Cache (Method)](CP11.ipynb#11.4)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[11.4.1 Exercise 1: Cache Misses](CP11.ipynb#11.4.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[11.4.2 Exercise 2: Cache Flow](CP11.ipynb#11.4.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[11.4.3 Exercise 3: Large-Matrix Multiplication](CP11.ipynb#11.4.3)<br>
# [11.5 Graphical Processing Units for High Performance Computing](CP11.ipynb#11.5)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[11.5.1 The GPU Card](CP11.ipynb#11.5.1)<br>
# [11.6 Practical Tips for Multicore & GPU Programming](CP11.ipynb#11.6)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[11.6.1 CUDA Memory Usage](CP11.ipynb#11.6.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[11.6.2 CUDA Programming](CP11.ipynb#11.6.2)<br>
#
# [**12 Fourier Analysis: Signals & Filters**](CP12.ipynb)<br>
# [12.1 Fourier Analysis of Nonlinear Oscillations](CP12.ipynb#12.1)<br>
# [12.2 Fourier Series (Math)](CP12.ipynb#12.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[12.2.1 Examples: Sawtooth & Half-Wave Functions](CP12.ipynb#12.2.1)<br>
# [12.3 Exercise: Summation of Fourier Series](CP12.ipynb#12.3)<br>
# [12.4 Fourier Transforms (Theory)](CP12.ipynb#12.4)<br>
# [12.5 The Discrete Fourier Transform](CP12.ipynb#12.5)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[12.5.1 Aliasing (Assessment)](CP12.ipynb#12.5.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[12.5.2 Fourier Series DFT (Example)](CP12.ipynb#12.5.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[12.5.3 Assessments](CP12.ipynb#12.5.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[12.5.4 Nonperiodic Function DFT (Exploration)](CP12.ipynb#12.5.4)<br>
# [12.6 Filtering Noisy Signals](CP12.ipynb#12.6)<br>
# [12.7 Noise Reduction via Autocorrelation (Theory)](CP12.ipynb#12.7)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[12.7.1 Exercises](CP12.ipynb#12.7.1)<br>
# [12.8 Filtering with Transforms (Theory)](CP12.ipynb#12.8)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;
1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[20.2.2 Solution: Time-Stepping](CP20.ipynb#20.2.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[20.2.3 Von Neumann Stability Assessment](CP20.ipynb#20.2.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[20.2.4 Heat Equation Implementation](CP20.ipynb#20.2.4)<br>
# [20.3 Assessment and Visualization](CP20.ipynb#20.3)<br>
# [20.4 Improved Heat Flow: Crank-Nicolson Method](CP20.ipynb#20.4)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[20.4.1 Solution of Tridiagonal Matrix Equations](CP20.ipynb#20.4.1)<br>
#  &nbsp;&nbsp;&nbsp;&nbsp;[20.4.2 Implementation, Assessment](CP20.ipynb#20.4.2)<br>
#
# [**21 Wave Equations I: Strings & Membranes**](CP21.ipynb)<br>
# [21.1 A Vibrating String](CP21.ipynb#21.1)<br>
# [21.2 The Hyperbolic Wave Equation (Theory)](CP21.ipynb#21.2) <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;[21.2.1 Solution via Normal-Mode Expansion](CP21.ipynb#21.2.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[21.2.2 Algorithm: Time-Stepping](CP21.ipynb#21.2.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[21.2.3 Wave Equation Implementation](CP21.ipynb#21.2.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[21.2.4 Assessment, Exploration](CP21.ipynb#21.2.4)<br>
# [21.3 Strings with Friction (Extension)](CP21.ipynb#21.3)<br>
# [21.4 Strings with Variable Tension & Density](CP21.ipynb#21.4)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[21.4.1 Waves on Catenary](CP21.ipynb#21.4.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[21.4.2 Derivation of Catenary Shape](CP21.ipynb#21.4.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[21.4.3 Catenary & Frictional Wave Exercises](CP21.ipynb#21.4.3)<br>
# [21.5 Vibrating Membrane (2-D Waves](CP21.ipynb#21.1)<br>
# [21.6 Analytical Solution](CP21.ipynb#21.6)<br>
# [21.7 Numerical Solution for 2-D Waves](CP21.ipynb#21.7)<br>
#
# [**22 Wave Equations II: Quantum Packets & E-M**](CP22.ipynb)<br>
# [22.1 QuantumWave Packets](CP22.ipynb#22.1)<br>
# [22.2 Time-Dependent Schrödinger Equation (Theory)](CP22.ipynb#22.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[22.2.1 Finite-Difference Algorithm](CP22.ipynb#22.2.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[22.2.2 Wave Packet Implementation, Animation](CP22.ipynb#22.2.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[22.2.3 Wave Packets in Other Wells (Exploration)](CP22.ipynb#22.2.3)<br>
# [22.3 Algorithm for the 2-D Schrödinger Equation](CP22.ipynb#22.3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[22.3.1 Exploration: Bound & Diffracted 2-D Packet](CP22.ipynb#22.3.1)<br>
# [22.4 Wavepacket–Wavepacket Scattering](CP22.ipynb#22.4)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[22.4.1 Algorithm](CP22.ipynb#22.4.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[22.4.2 Implementation](CP22.ipynb#22.4.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[22.4.3 Results and Visualization](CP22.ipynb#22.4.3)<br>
# [22.5 E&MWaves via Finite-Difference Time Domain](CP22.ipynb#22.5)<br>
# [22.6 Maxwell’s Equations](CP22.ipynb#22.6)<br>
# [22.7 FDTD Algorithm](CP22.ipynb#22.7)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[22.7.1 Implementation](CP22.ipynb#22.7.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[22.7.2 Assessment](CP22.ipynb#22.7.2)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;
1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[25.2.4 Successive Overrelaxation Implementation](CP25.ipynb#25.1)<br>
# [25.3 2-D Flow over a Beam](CP25.ipynb#25.1)<br>
# [25.4 Theory: Vorticity Form of Navier-Stokes Equation](CP25.ipynb#25.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[25.4.1 Finite Differences and the SOR Algorithm](CP25.ipynb#25.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[25.4.2 Boundary Conditions for a Beam](CP25.ipynb#25.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[25.4.3 SOR on a Grid](CP25.ipynb#25.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[25.4.4 Flow Assessment](CP25.ipynb#25.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[25.4.5 Exploration](CP25.ipynb#25.1)<br>
#
# [**26 Integral Equations of Quantum Mechanics**](CP26.ipynb)<br>
# [26.1 Bound States of Nonlocal Potentials](CP26.ipynb#26.1)<br>
# [26.2 Momentum-Space Schrödinger Equation (Theory)](CP26.ipynb#26.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[26.2.1 Integral to Matrix Equations](CP26.ipynb#26.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[26.2.2 Delta-Shell Potential (Model)](CP26.ipynb#26.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[26.2.3 Binding Energies Solution](CP26.ipynb#26.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[26.2.4 Wave Function (Exploration)](CP26.ipynb#26.1)<br>
# [26.3 Scattering States of Nonlocal Potentials](CP26.ipynb#26.1)<br>
# [26.4 Lippmann-Schwinger Equation (Theory)](CP26.ipynb#26.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[26.4.1 Singular Integrals (Math)](CP26.ipynb#26.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[26.4.2 Numerical Principal Values](CP26.ipynb#26.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[26.4.3 Reducing Integral to Matrix Equations](CP26.ipynb#26.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[26.4.4 Solution via Inversion, Elimination](CP26.ipynb#26.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[26.4.5 Scattering Implementation](CP26.ipynb#26.1)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[26.4.6 Scattering Wave Function (Exploration)](CP26.ipynb#26.1)<br>
# [**A Codes, Applets & Animations**](Append.ipynb)<br>
# [**Bibliography**](Biblio.ipynb)

# %% [markdown]
# # Preface to Python Notebook Version
#
# >The more I think of it I find this conclusion more impressed upon me — that the greatest thing a human soul ever does in this world is to see something, and tell what it saw in a plain way. Hundreds of people can talk for one who can think, but thousands can think for one who can see. <br>- John Ruskin
#
# This Python notebook version of *Computational Physics* is the latest realization of our  decades long exploration of models for eTextBooks (see [*Visions and Realizations of a Computational eTextbook*, Computing in Science and Engineering **17(5)**,72-79, August 2015](http://physics.oregonstate.edu/~landaur/Papers/LandauCPbook.pdf)). As the reader of that CiSE article may note, our two biggest struggles have been comingling executable code into publishable text in a legal manor, and  getting publishers to publish some version of our interactive electronic text. The collection of Jupyter/iPython notebooks presented here, with each chapter of our text placed in a separate notebook, represents a big step towards reaching our goal of an "executable text".  In addition to  the familiar Web-based multimedia extensions and hyperlinks, the Python version (.ipynb not .html) permits the Python codes to be executed, modified  and produce visualizations as you read the book.  The price paid for executable text is the need to read the book on a computer and within the Jupyter version of a Python environment, although the HTML version of the notebooks can be read in an ordinary browser. (There was also a price to pay in making yet another eBook version, but that's yet another story.)
#
# A specific discussion of requisite browsers and media players is given in Section 1.0, along with more ideas about eBooks. A discussion of Python is given below in the *Preface to Printed Third Edition* as well as in *Chapter 1.*
#
# The eBook versions of the text  permit an instructor to remove unneeded sections or add their own materials as desired. The authors and publisher Wiley-VCH still maintain copyrights over the materials. We ask that you acknowledge us if you use or modify the materials, and that you respect  all applicable copyright laws.
#
# The codes in the notebooks are essentially identical to those in the paper text, with the biggest change being the need to replace the paper text's use of the *Visual* package by the *iVisual* package designed for notebooks. No change is needed for those codes that use *MatPlotLib* (which is similar to *MatLab* graphics). This is our first use of the notebook format and so some parts may not be as well done as possible. We welcome suggestions for the future.
#
# Finally, and in deep sadness, we must note that the junior member of the coauthors, Cristian Bordeianu, passed away just as the paper version of the third edition was coming out. We miss him terribly and dedicate this version to the memory of his contributions and especially his friendship.
#
# <br>
# -- RHL, Tucson, January 2016

# %% [markdown]
# # Preface to Printed Third Edition
#
# Seventeen years have past since Wiley’s first published Landau and
# Páez’s *Computational Physics* and seven years since Cristian Bordeianu
# joined the collaboration for the second edition. This third edition
# adheres to the original philosophy that the best way to learn
# computational physics (CP) is by working on a wide range of projects
# using the text and the computer as partners. Most projects are still
# constructed using a computational, scientific problem-solving paradigm:
#  Our guiding hypothesis remains that CP is a
# computational science, which means that to understand CP you need to
# understand some physics, some applied mathematics and some computer
# science. What’s different in this edition is the choice of Python for
# sample codes and an increase in the number of topics covered. We now
# have a survey of CP which is more than enough for a full-year’s course.
#
# The use of Python is more than just a change of language, it is taking
# advantage of the Python ecosystem of base language plus multiple,
# specialized libraries to provide all computational needs. In addition,
# we find Python to be the easiest and most accessible language for
# beginners, while still being excellent for the type of interactive and
# exploratory computations now popular in scientific research.
# Furthermore, Python supplemented by the Visual package (Vpython) has
# gained traction in lower-division physics teaching, and this may serve
# as an excellent segue to a Python-based CP course. Nevertheless, the
# important aspects of computational modeling and thinking transcends any
# particular computer language, and so having a Python alternative to our
# previous use of Fortran, C and Java may help promote this view (codes in
# all languages are available).
#
# As before, we advocate for the use of a compiled or interpreted
# programming language when learning CP, in contrast to a higher-level
# problem-solving environment like Mathematica or Maple, which we use in
# daily work. This follows from our experiences that if you want to
# *understand* how to compute scientifically, then you must look inside a
# program’s black box and get your hands dirty. Otherwise, the algorithms,
# logic and the validity of solutions cannot be ascertained, and that is
# not a good physics. Not surprisingly, we believe all physicists should
# know how to read programs how to write them as well.
#
# Notwithstanding our beliefs about programming, we appreciate how
# time-consuming and frustrating debugging programs often is, and
# especially for beginners. Accordingly, rather than make the learner
# write all codes from scratch, we have placed a large number of codes
# within the text and often ask the learner only to run, modify, and
# extend them. This not only leaves time for exploration and analysis, but
# also provides experience in the modern work environment in which one
# must incorporate new developments into the preexisting codes of others.
# Be that as it may, for this edition we have added problems in which the
# relevant codes are not in the text (but are available to instructors).
# This should permit an instructor to decide on the balance of new and
# second-hand codes with which their students should work.
#
# In addition to the paper version of the text, there is also an eBook of
# it that incorporates many of the multimodal enhancements possible with
# modern technologies: video lecture modules, active simulations, editable
# codes, animations and sounds. The eBook is available as a Web (HTML5)
# document appropriate for both PC’s or mobile devices. The lecture
# modules, which can be viewed separately from the eBook, cover most of
# the topics in the text, are listed in Appendix B, and are available
# online. They may provide avenues for alternative understanding the text
# (either as a preview or a review), for an online course, or for a
# blended course that replaces some lecture time with lab time. This
# latter approach, which we recommend, provides time for the instructor to
# assist students more personally with their projects and their learning
# issues. The studio-produced lectures are truly “modules”, with active
# slides, a dynamic table of context, excellent sound (except maybe for a
# Bronx accent), and with occasional demonstrations replacing the talking
# head.
#
# The introductory chapter includes tables listing all of the problems and
# exercises in the text, their locations in the text, as well as the
# physics courses in which these problems may be used as computational
# examples. Although we think it is better to have entire courses in CP
# rather than just examples in traditional courses, the inclusion of
# examples may serve as a valuable first step towards modernization.
#
# The entire book has been reedited to improve clarity and useability. New
# materials have also been added, and this has led to additional and
# reorganized chapters. Specific additions not found in the second edition
# include: descriptions of the Python language and its packages,
# demonstrations of several visualization packages, discussions of
# algebraic tools, an example on protein folding, a derivation of the
# Gaussian quadrature rule, searching to obtain the temperature dependence
# of magnetization, chaotic weather patterns, planetary motion, matrix
# computing with Numerical Python, expanded and updated discussion of
# parallel computing including scalability and domain composition,
# optimized matrix computing with NumPy, GPU computing, CUDA programming,
# principal components analysis, digital filtering, the Fast Fourier
# Transform (FFT), an entire chapter on wavelet analysis and data
# compression, a variety of predator-prey models, signals of chaos,
# nonlinear behavior of double pendulum, cellular automata, Perlin noise,
# ray tracing, Wang-Landau sampling for thermodynamic simulations, finite
# *element* (in addition to *difference*) solutions of 1-D and 2-D PDE’s,
# waves on a catenary, finite-difference-time-domain solutions for E&M
# waves, advection and shock waves in fluids, and a new chapter on fluid
# dynamics. We hope you enjoy it all!
#
# <br>
# -- RHL, Redmond, Oregon, June 2014
#
# ## Acknowledgements
#
# > <span>*Immature poets imitate;<br>
# > mature poets steal.  — T. S. Elliot*</span>
#
# This book and the courses it is based upon could not have been created
# without continued financial support from the National Science
# Foundation’s CCLI, EPIC, and NPACI programs, as well as support from the
# Oregon State University. Thank you all and we hope we have done you
# proud.
#
# Our CP developments have followed the pioneering path paved by the books
# of Thompson, Gould & Tobochnik, Koonin and Press *et al.*; indubitably,
# we have borrowed material from them and made it our own with no further
# thought. We wish to acknowledge valuable contributions by Hans Kowallik,
# Sally Haerer (video lecture modules), Paul Fink, Michel Vallières, Joel
# Wetzel, Oscar A. Restrepo, Jaime Zuluaga, Pavel Snopok and Henri Jansen.
# It is our pleasure to acknowledge the invaluable friendship,
# encouragement, helpful discussions, and experiences we have had with
# many colleagues and students over the years. We are particularly
# indebted to Guillermo Avendaño-Franco, Saturo S. Kano, Melanie Johnson,
# Jon Maestri (deceased), David McIntyre, Shashikant Phatak, Viktor
# Podolskiy, C. E. Yaguna, Zlatco Dimcovic and Al Stetz. The new work on
# principal component analysis resulted from a wonderful collaboration
# with Jon Wright and Roy Schult in 1997. Our gratitude also goes to the
# reviewers for their thoughtful and valuable suggestions, and to Bruce
# Sherwood, who has assisted us in making the Python codes run faster and
# look better. And finally, Ann Seidel, Martin Preuss, Nina Stadthuas and
# Vera Palmer at Wiley-VCH have been a pleasure to work with.
#
# In spite of everyone’s best efforts, there are still errors and
# confusing statements in the book and codes for which we are to blame.
#
# Finally, we extend our gratitude to the wives, Jan and Lucia, whose
# reliable support and encouragement are lovingly accepted, as always.
