# %% [markdown]
# # Bibliography
#
# | | | |
# |:---:|:---:|:---:|
# | ![image](Figs/Cover.png)|[From **COMPUTATIONAL PHYSICS**, 3rd Ed, 2015](http://physics.oregonstate.edu/~rubin/Books/CPbook/index.html) <br>RH Landau, MJ Paez, and CC Bordeianu (deceased) <br>Copyrights: <br> [Wiley-VCH, Berlin;](http://www.wiley-vch.de/publish/en/books/ISBN3-527-41315-4/) and [Wiley & Sons, New York](http://www.wiley.com/WileyCDA/WileyTitle/productCd-3527413154.html)<br>  R Landau, Oregon State Unv, <br>MJ Paez, Univ Antioquia,<br> C Bordeianu, Univ Bucharest, 2015.<br> Support by National Science Foundation.|![image](Figs/BackCover.png)|
#
# <span style="font-variant:small-caps;">Abarbanel, H. D. I., M. I.
# Rabinovich and M. M. Sushchik</span> (1993), *Introduction to Nonlinear
# Dynamics for Physicists,* World Scientific, Singapore.
#
# <span style="font-variant:small-caps;">Abramowitz, M., and I. A.
# Stegun</span> (1972), *Handbook of Mathematical Functions,* 10th Ed.
# U.S. Govt. Printing Office, Washington.
#
# <span style="font-variant:small-caps;">Addison, P. S.</span> (2002),
# *The Illustrated Wavelet Transform Handbook,* Institute of Physics
# Publishing, Bristol and Philadelphia.
#
# <span style="font-variant:small-caps;">Allan, M. P., and J. P.
# Tildesley</span> (1987), *Computer Simulations of Liquids,* Oxford
# Science Publications, Oxford.
#
# <span style="font-variant:small-caps;">Amdahl, G.</span> (1967),
# *Validity of the Single-Processor Approach to Achieving Large-Scale
# Computing Capabilities*, Proc. AFIPS., 483.
#
# <span style="font-variant:small-caps;">Ancona, M. G.</span> (2002),
# *Computational Methods for Applied Science & Engineering,* Rinton Press,
# Princeton.
#
# <span style="font-variant:small-caps;">Anderson, E., Z. Bai, C. Bischof,
# J. Demmel, J. Dongarra, J. Du Croz, A. Greenbaum, S. Hammarling, A.
# McKenney, S. Ostrouchov and D. Sorensen</span> (2013), *LAPACK Users’
# Guide*, 3rd Ed.,  SIAM, Philadelphia;
# [www.netlib.org.](http://www.netlib.org)
#
# <span style="font-variant:small-caps;">Anderson, J. A., C. D. Lorenz and
# A. Travesset</span> (2008), *HOOMD-blue, General purpose molecular
# dynamics simulations*, J. Compt. Phys. **227(10)**,  5342;
# [codeblue.umich.edu/hoomd-blue](http://codeblue.umich.edu/hoomd-blue/).
#
# <span style="font-variant:small-caps;">Arfken, G. B., and H. J.
# Weber</span> (2001), *Mathematical Methods for Physicists,*
# Harcourt/Academic Press, San Diego.
#
# <span style="font-variant:small-caps;">Argyris, J., M. Haase, and J. C.
# Heinrich</span> (1991), <span>Comput. Meth. Appl. Mech. Eng.</span>,
# **86**, 1.
#
# <span style="font-variant:small-caps;">Armin, B., and H. Shlomo,
# (Eds.)</span> (1991), *Fractals and Disordered Systems*, Springer,
# Berlin.
#
# <span style="font-variant:small-caps;">Askar, A., and A. S.
# Cakmak</span> (1977), <span>J. Chem. Phys.</span> **68**, 2794.
#
# <span style="font-variant:small-caps;">Banacloche, J. G.</span> (1999),
# *A Quantum Bouncing Ball*, <span>Am. J. Phys.</span> **67**, 776.
#
# <span style="font-variant:small-caps;">Barnsley, M. F., and L. P.
# Hurd</span> (1992), *Fractal Image Compression*, A. K. Peters,
# Wellesley.
#
# <span style="font-variant:small-caps;">Beazley, D. M.</span> (2009),
# *Python Essential Reference*, 4th Ed., Addison-Wesley, Reading.
#
# <span style="font-variant:small-caps;">Becker, R. A.</span> (1954),
# *Introduction to Theoretical Mechanics*, McGraw-Hill, New York.
#
# <span style="font-variant:small-caps;">Bevington, P. R., and D. K.
# Robinson</span> (2002), *Data Reduction and Error Analysis for the
# Physical Sciences*, 3rd Ed., McGraw-Hill, New York.
#
# <span style="font-variant:small-caps;">Bleher, S., C. Grebogi, and E.
# Ott</span> (1990), *Bifurcations in Chaotic Scattering*, Physica D,
# **46**, 87.
#
# <span style="font-variant:small-caps;">Briggs, W. L., and V. E.
# Henson</span> (1995), *The DFT, An Owner’s Manual*, SIAM, Philadelphia.
#
# <span style="font-variant:small-caps;">Bunde, A., and S. Havlin,
# (Eds.)</span> (1991), *Fractals and Disordered Systems*, Springer,
# Berlin.
#
# <span style="font-variant:small-caps;">Burgers, J. M.</span> (1974),
# *The Non-Linear Diffusion Equation; Asymptotic Solutions and
# Stattistical Problems*, Reidel, Boston.
#
# <span style="font-variant:small-caps;">Car, R., and M. Parrinello</span>
# (1985), <span>Phys. Rev. Lett.</span> **55,** 2471.
#
# <span style="font-variant:small-caps;">Cencini, M., F.Ceconni and A.
# Vulpiani</span> (2010), *Chaos From Simple Models To Complex Systems*,
# World Scientific, Singapore.
#
# <span style="font-variant:small-caps;">Christiansen, P. L., and P. S.
# Lomdahl</span> (1981), <span>Physica D,</span> **2**, 482.
#
# <span style="font-variant:small-caps;">Christiansen, P. L., and O. H.
# Olsen</span> (1978), <span>Phys. Lett.</span> **68A,** 185; (1979),
# <span>Physica Scripta</span> **20**, 531.
#
# <span style="font-variant:small-caps;">Computing in Science &
# Engineering</span>, Thiruvathukal, G. K., Ed, (2015); Perez, F., B. E.
# Granger and J. D . Hunter, *Python: An Ecosystem for Scientific
# Computing,* March/April 2011.
#
# <span style="font-variant:small-caps;">Clark University</span> (2011),
# *Statistical & Thermal Physics Curriculum Development Project*,
# [stp.clarku.edu/](http://stp.clarku.edu/); *Density of States of the 2D
# Ising Model*.
#
# <span style="font-variant:small-caps;">CPUG, Computational Physics
# degree program for Undergraduates</span> (2009),
# [physics.oregonstate.edu/CPUG](http://physics.oregonstate.edu/CPUG).
#
# (1946), <span>Procd. Cambridge Phil. Soc.</span> **43,** 50.
#
# <span>cootu</span> <span style="font-variant:small-caps;">Cooley, J. W.,
# and J. W. Tukey</span> (1965), <span>Math. Comput.</span>, **19**, 297.
#
# <span style="font-variant:small-caps;">Courant, R., K. Friedrichs and H.
# Lewy</span> (1928), <span>Math. Ann.</span> **100**, 32.
#
# <span style="font-variant:small-caps;">Critchley, S.</span> (2 February
# 2014), *The Dangers of Certainty: A Lesson from Auschwitz*, New York
# Times.
#
# <span>dala</span> <span style="font-variant:small-caps;">Danielson, G.
# C., and C. Lanczos</span> (1942), <span>J. Franklin Inst.</span>,
# **233**, 365.
#
# <span style="font-variant:small-caps;">Daubechies, I.</span> (1995),
# *Wavelets and other phase domain localization methods*, Proc. Int. Cong.
# Math., **1, 2**, Basel, 56 (1995). Birkhäuser, Basel.
#
# <span style="font-variant:small-caps;">DeJong, M. L.</span> (1992),
# *Chaos and the Simple Pendulum,* <span>The Physics Teacher</span>
# **30**, 115.
#
# <span style="font-variant:small-caps;">Dongarra, J.</span> (2011), *On
# the Future of High Performance Computing: How to Think for Peta and
# Exascale Computing*, Conference on Computational Physics 2011,
# Gatlinburg; *Emerging Technologies for High Performance Computing*, GPU
# Club presentation, 2011, University of Manchester,
# [www.netlib.org/utk/people/
# JackDongarra/SLIDES/gpu-0711.pdf](http://www.netlib.org/utk/people/\ JackDongarra/SLIDES/gpu-0711.pdf).
#
# <span style="font-variant:small-caps;">Dongarra, J., T. Sterling, H.
# Simon and E. Strohmaier</span> (2005), *High-Performance Computing,*
# Comp. in Science & Engr. **7**, 51.
#
# <span style="font-variant:small-caps;">Dongarra, J., Hittinger, J.,
# Bell, J., Chacson, L., Falgout, R., Heroux, M., Hovland, P., Ng, E.,
# Webster, C. and Wild, S.</span> (2014), *Applied Mathematics Research
# for Exascale Computing,* U. S. Dept. of Energy Report, March 2014,
# <http://www.osti.gov/bridge>.
#
# <span style="font-variant:small-caps;">Donnelly, D., and B. Rust</span>
# (2005), *The Fast Fourier Transform for Experimentalists,* Comp. in
# Science & Engr. **7**, 71.
#
# <span style="font-variant:small-caps;">Eclipse</span> an open
# development platform, (2014),
# [www.eclipse.org](http://www.eclipse.org/).
#
# <span>erco</span><span style="font-variant:small-caps;">Ercolessi,
# F.</span> (1997), *A Molecular Dynamics Primer*,
# [www.ud.infn.it/\~ercolessi/md/](http://www.ud.infn.it/~ercolessi/md/).
#
# <span style="font-variant:small-caps;">Faber, R.</span> (2010), *CUDA,
# Supercomputing for the Masses: Part 15*, [www.drdobbs.com/\
# architecture-and-design/cuda-supercomputing-\
# for-the-masses-part/222600097](http://www.drdobbs.com/architecture-and-design/cuda-supercomputing-for-the-masses-part/222600097).
#
# <span style="font-variant:small-caps;">Falkovich, G., and K. R.
# Sreenivasan</span> (2006), *Lesson from Hydrodynamic Turbulence*,
# <span>Physics Today</span>, **59**, 43.
#
# <span style="font-variant:small-caps;">Family, F., and T. Vicsek</span>
# (1985), <span>J. Phys. A</span> **18**, L75.
#
# <span style="font-variant:small-caps;">Feigenbaum, M. J.</span> (1979),
# <span>J. Stat. Physics</span> **21**, 669.
#
# <span style="font-variant:small-caps;">Fetter, A. L., and J. D.
# Walecka</span> (1980), *Theoretical Mechanics of Particles and
# Continua*, McGraw-Hill, New York.
#
# <span style="font-variant:small-caps;">Feynman, R. P., and A. R.
# Hibbs</span> (1965), *Quantum Mechanics and Path Integrals*,
# McGraw-Hill, New York.
#
# <span style="font-variant:small-caps;">Fitzgerald, R.</span> (2004),
# *New Experiments Set the Scale for the Onset of Turbulence in Pipe
# Flow*, <span>Phys. Today</span>, **57**, 21.
#
# <span>fosdick</span><span style="font-variant:small-caps;">Fosdick L. D,
# E. R. Jessup, C. J. C. Schauble and G. Domik</span> (1996), *An
# Introduction to High Performance Scientific Computing*, MIT Press,
# Cambridge.
#
# <span style="font-variant:small-caps;">Fox, G.</span> (1994), *Parallel
# Computing Works!*, Morgan Kaufmann, San Diego.
#
# <span>Gara</span> <span style="font-variant:small-caps;">Gara, A., M. A.
# Blumrich, D. Chen, G. L.-T. Chiu, P. Coteus, M. E. Giampapa, R. A.
# Haring, P. Heidelberger, D. Hoenicke, G. V. Kopcsay, T. A. Liebsch, M.
# Ohmacht, B. D. Steinmacher-Burow, T. Takken and P. Vranas</span> (2005),
# *Overview of the Blue Gene/L system architecure,* IBM J. Res & Dev
# **49**, 195; Feldman, M., *IBM Specs Out Blue Gene/Q Chip*, HPC Wire,
# August 22, 2011.
#
# <span>garcia</span> <span style="font-variant:small-caps;">Garcia, A.
# L.</span> (2000), *Numerical Methods for Physics*, 2nd Ed., Prentice
# Hall, Upper Saddle River.
#
# <span>gibbs</span> <span style="font-variant:small-caps;">Gibbs, R.
# L.</span> (1975), *The quantum bouncer*, Am. J. Phys., **43**, 25.
#
# <span>goodings</span> <span style="font-variant:small-caps;">Goodings,
# D. A., and T. Szeredi</span> (1992), *The quantum bouncer by the path
# integral method*, Am. J. Phys., **59**, 924.
#
# <span style="font-variant:small-caps;">Gnuplot home page</span> (2014),
# [www.gnuplot.info](http://www.gnuplot.info/).
#
# <span style="font-variant:small-caps;">Goswani, J. C., and A. K.
# Chan</span> (1999), *Fundamentals of Wavelets*, Wiley, New York.
#
# <span>gott</span> <span style="font-variant:small-caps;">Gottfried,
# K.</span> (1966), *Quantum Mechanics*, Benjamin, New York.
#
# <span style="font-variant:small-caps;">Gould, H., J. Tobochnik and W.
# Christian</span> (2006), *An Introduction to Computer Simulations
# Methods*, 3rd Ed., Addison-Wesley, Reading.
#
# <span style="font-variant:small-caps;">Graps, A.</span> (1995), *An
# Introduction to Wavelets,* Comp. in Science & Engr. **2**, 50.
#
# <span style="font-variant:small-caps;">Gurney, W. S. C., and R. M.
# Nisbet</span> (1998), *Ecological Dynamics*, Oxford Uni. Press, Oxford.
#
# <span>ht</span><span style="font-variant:small-caps;">Haftel, M. I., and
# F. Tabakin</span> (1970), <span>Nucl. Phys.</span> **158**, 1.
#
# <span style="font-variant:small-caps;">Hardwich, J.</span> (1996),
# *Rules for Optimization,*
# [www.cs.cmu.edu/\~jch/java.](http://www.cs.cmu.edu/~jch/java)
#
# <span style="font-variant:small-caps;">Hartmann, W. M.</span> (1998),
# *Signals, Sound, and Sensation*, AIP Press, Springer, New York.
#
# <span style="font-variant:small-caps;">Higgins, R. J.</span> (1976),
# *Fast Fourier transform: An introduction with some minicomputer
# experiments*, <span>Am. J. Phys.</span>, **44**, 766.
#
# <span style="font-variant:small-caps;">Hildebrand, F. B.</span> (1956),
# <span style="font-variant:small-caps;">Introduction to Numerical
# Analysis</span>, McGraw-Hill, New York.
#
# <span style="font-variant:small-caps;">Hinsen, K.</span> (2013)
# *Software development for reproducible research*, Comput. Sci. Eng, no
# 4, 15, 60-63.
#
# <span style="font-variant:small-caps;">History of Python</span> (2009),
# [python-history.blogspot.com/2009/\
# 01/brief-timeline-of-python.html](http://python-history.blogspot.com/2009/01/brief-timeline-of-python.html).
#
# <span style="font-variant:small-caps;">Hockney, R.W., and J.W.
# Eastwood</span> (1988), *Computer Simulation Using Particles*, Adam
# Hilger, Bristol.
#
# <span style="font-variant:small-caps;">Hubble, E.</span> (1929), *A
# Relation between distance and radial velocity among extra-galactic
# nebulae,* Proc. Nat. Academy of Sciences, **15:(3)**, 168.
#
# <span style="font-variant:small-caps;">Hunag, K.</span> (1987),
# *Statistical Mechanics*, Wiley, New York.
#
# <span style="font-variant:small-caps;">Jackson, J. D.</span> (1988),
# *Classical Electrodynamics*, 3rd Ed., Wiley, New York.
#
# <span style="font-variant:small-caps;">José, J. V, and E. J.
# Salatan</span> (1988), *Classical Dynamics*, Cambridge Univ. Press,
# Cambridge.
#
# <span style="font-variant:small-caps;">Kennedy, R.</span> (2006), *The
# case of Pollock’s Fractals Focuses on Physics*, New York Times, 2,5
# December 2006.
#
# <span style="font-variant:small-caps;">Kirk, D., and W. H.
# Wen-Mei</span> (2013), *Programming Massively Parallel Processors, 2nd
# Ed.*, Morgan Kauffman, Waltham.
#
# <span style="font-variant:small-caps;">Kittel, C.</span> (2005),
# *Introduction to Solid State Physics*, 8th Ed., Wiley, New York.
#
# <span style="font-variant:small-caps;">Klöckner, A.</span> (2014),
# *PyCUDA*,
# [mathema.tician.de/software/pycuda](http://mathema.tician.de/software/pycuda/).
#
# <span style="font-variant:small-caps;">Koonin, S. E.</span> (1986),
# *Computational Physics*, Benjamin, Menlo Park, CA.
#
# <span style="font-variant:small-caps;">Korteweg, D. J., and G.
# deVries</span> (1895), <span>Phil. Mag.</span>, **39**, 4.
#
# <span style="font-variant:small-caps;">Kreyszig, E.</span> (1998),
# *Advanced Engineering Mathematics*, 8th Ed., Wiley, New York.
#
# <span style="font-variant:small-caps;">Lamb, H.</span> (1993),
# *Hydrodynamics*, 6th Ed., Cambridge University Press, Cambridge.
#
# <span style="font-variant:small-caps;">Landau, D. P., and F. Wang</span>
# (2001), *Determining the density of states for classical statistical
# models: A random walk algorithm to produce a flat histogram*, Phys. Rev.
# E, **64**, 056101; <span style="font-variant:small-caps;">Landau, D. P,
# S.-H. Tsai and M. Exler</span> (2004), *A new approach to Monte Carlo
# simulations in statistical physics: Wang-Landau sampling*, Am. J. Phys.,
# **72**, 1294.
#
# <span style="font-variant:small-caps;">Landau, L. D., and E. M.
# Lifshitz</span> (1987), *Fluid Mechanics*, 2nd Ed.,
# Butterworth-Heinemann, Oxford.
#
# <span style="font-variant:small-caps;">Landau, L. D., and E. M.
# Lifshitz</span> (1976), *Quantum Mechanics*, Pergamon, Oxford.
#
# <span style="font-variant:small-caps;">Landau, L. D., and E. M.
# Lifshitz</span> (1976), *Mechanics*, 3rd Ed., Butterworth-Heinemann,
# Oxford.
#
# <span style="font-variant:small-caps;">Landau, R. H.</span> (2008),
# *Resource Letter CP-2: Computational Physics,* Am. J. Phys., **76**,
# 296.
#
# <span style="font-variant:small-caps;">Landau, R. H.</span> (2005), *A
# First Course in Scientific Computing*, Princeton Univ. Press, Princeton.
#
# <span style="font-variant:small-caps;">Landau, R. H.</span> (1996),
# *Quantum Mechanics II, A Second Course in Quantum Theory*, 2nd Ed.,
# Wiley, New York.
#
# <span style="font-variant:small-caps;">Lang, W. C., K. Forinash</span>
# (1998), *Time-frequency analysis with the continuous wavelet transform*,
# Amer. J. of Phys, **66**, 794.
#
# <span style="font-variant:small-caps;">Langtangen, H. P.</span> (2008),
# *Python Scripting for Computational Science*, Springer, Heidelberg.
#
# <span style="font-variant:small-caps;">Langtangen, H. P.</span> (2009),
# *A Primer on Scientific Programming with Python*, Springer, Heidelberg.
#
# <span style="font-variant:small-caps;">Li, Z.</span> *Numerical Methods
# for Partial Differential Equations —- Finite Element Method*, (2014),
# [www4.ncsu.edu/\~zhilin/](http://www4.ncsu.edu/~zhilin/).
#
# <span style="font-variant:small-caps;">Lorenz, E. N.</span> (1963),
# *Deterministic Non-periodic Flow*, J. Atmos. Sci., **20**,130.
#
# <span style="font-variant:small-caps;">Lotka, A. J.</span> (1925),
# *Elements of Physical Biology*, Williams & Wilkins, Baltimore.
#
# <span style="font-variant:small-caps;">MacKeown, P. K.</span> (1985),
# <span>Am. J. Phys.,</span> **53**, 880.
#
# <span style="font-variant:small-caps;">MacKeown, P. K., and D. J.
# Newman</span> (1987), *Computational Techniques in Physics*, Adam
# Hilger, Bristol.
#
# <span style="font-variant:small-caps;">Maestri, J. J. V., R. H. Landau
# and M. J. Páez</span> (2000), *Two-Particle Schrödinger Equation
# animations of wave packet-wave packet scattering*, Am. J. Phys., **68**,
# 1113; movies at
# <http://physics.oregonstate.edu/~rubin/nacphy/ComPhys/PACKETS/>.
#
# <span style="font-variant:small-caps;">Mallat, P.G.</span> (1982), *A
# Theory for Multiresolution Signal Decomposition: The Wavelet
# Representation*, IEEE Transaction on Pattern Analysis and Machine
# Intelligence, **11, No.7,** 674.
#
# <span style="font-variant:small-caps;">Mandelbrot, B.</span> (1967),
# *How long is the coast of Britain?*, <span>Science</span>, **156**, 638.
#
# <span style="font-variant:small-caps;">Mandelbrot, B.</span> (1982),
# *The Fractal Geometry of Nature*, Freeman, San Francisco.
#
# <span style="font-variant:small-caps;">Manneville, P.</span> (1990),
# *Dissipative Structures and Weak Turbulence*, Academic Press, San Diego.
#
# <span style="font-variant:small-caps;">Mannheim, P. D.</span> (1983),
# *The physics behind path integrals in quantum mechanics*, <span>Am. J.
# Phys.,</span> **51**, 328.
#
# <span style="font-variant:small-caps;">Marion, J. B., and S. T.
# Thornton</span> (2003), *Classical Dynamics of Particles and Systems*,
# 5th Ed., Harcourt Brace Jovanovich, Orlando.
#
# <span style="font-variant:small-caps;">Mathews, J.</span> (2002),
# *Numerical Methods for Mathematics, Science and Engineering*, Prentice
# Hall, Upper Saddle River.
#
# <span style="font-variant:small-caps;">Metropolis, M., A. W. Rosenbluth,
# M. N. Rosenbluth, A. H. Teller and E. Teller</span> (1953), <span>J.
# Chem. Phys.</span> **21**, 1087.
#
# <span style="font-variant:small-caps;">Moon, F. C. and G.-X. Li</span>
# (1985), <span>Phys. Rev Lett.,</span> **55**, 1439.
#
# <span style="font-variant:small-caps;">Morse, P. M., and H.
# Feshbach</span> (1953), *Methods of Theoretical Physics*, McGraw-Hill,
# New York.
#
# <span style="font-variant:small-caps;">Motter, A and D. Campbell</span>
# (2013), *Chaos at fifty*, Physics Today, 66 (5), 27.
#
# <span style="font-variant:small-caps;">Nelson, M., W. Humphrey, A.
# Gursoy, A. Dalke, L. Kale, R. D. Skeel and K. Schulten</span> (1996),
# *NAMD - Scalable Molecular Dynamics*, J. of Supercomp. Apps. & High
# Perform. Comput., 10, 251-268,
# [www.ks.uiuc.edu/Research/namd](http://www.ks.uiuc.edu/Research/namd/).
#
# <span style="font-variant:small-caps;">Nesvizhevsky, V.V., H. G. Borner,
# A. K. Petukhov, H. Abele, S. Baessler, F. J. Ruess, T. Stoferle, A.
# Westphal, A. M. Gagarski, G. A. Petrov and A. V. Strelkov</span> (2002),
# *Quantum states of neutrons in the Earth’s gravitational field*, Nature,
# **415**, 297.
#
# <span style="font-variant:small-caps;">Numerical Python</span>, NumPy
# (2013), [numpy.scipy.org](http://numpy.scipy.org).
#
# <span style="font-variant:small-caps;">NumPy Tutorial, Tentative</span>
# (2012),
# [wiki.scipy.org/Tentative$\_$NumPy$\_$Tutorial](http://wiki.scipy.org/Tentative_NumPy_Tutorial).
#
# <span style="font-variant:small-caps;">Oliphant, T. E.</span> (2006),
# *Guide to NumPy*, [csc.ucdavis.edu/\~chaos/\
# courses/nlp/Software/NumPyBook.pdf](http://csc.ucdavis.edu/~chaos/courses/nlp/Software/NumPyBook.pdf).
#
# <span style="font-variant:small-caps;">Ott, E.</span> (2002), *Chaos in
# Dynamical Systems*, Cambridge University Press, Cambridge.
#
# <span style="font-variant:small-caps;">Otto A.</span> (2011), *Numerical
# Simulations of Fluids and Plasmas*,
# [how.gi.alaska.edu/ao/sim](http://how.gi.alaska.edu/ao/sim/).
#
# <span style="font-variant:small-caps;">Pancake, C. M.</span> (1996), *Is
# Parallelism for You?*, Computational Sci. & Engr, **3**, 18.
#
# <span style="font-variant:small-caps;">Peitgen, H.-O., H. Jürgens and D.
# Saupe</span> (1992), *Chaos and Fractals*, Springer, New York.
#
# <span style="font-variant:small-caps;">Penna, T. J. P.</span> (1994),
# <span>Comput. in Phys.,</span> **9**, 341.
#
# <span style="font-variant:small-caps;">Perlin, K.</span> (1985), *An
# Image Synthesizer*, Computer Graphics, Proceedings of ACM SIGGRAPH 85,
# 24 . 3.
#
# <span style="font-variant:small-caps;">Phatak, S. C., and S. S.
# Rao</span> (1995), *Logistic map: A possible random-number generator,*
# Phys. Rev. E, **51**, 3670.
#
# <span style="font-variant:small-caps;">Plischke, M., and B.
# Bergersen</span> (1994), *Equilibrium Statistical Physics*, 2nd Ed.,
# World Scientific Pub. Co., Singapore.
#
# <span style="font-variant:small-caps;">Polikar, R.</span> (2001), *The
# Wavelet Tutorial*, [users.rowan.edu/\~polikar/WAVELETS/\
# WTtutorial.html](http://users.rowan.edu/~polikar/WAVELETS/WTtutorial.html).
#
# <span style="font-variant:small-caps;">Polycarpou, A. C.</span> (2006),
# *Introduction to the Finite Element Method in Electromagnetics*, Morgan
# & Claypool, San Rafael.
#
# <span style="font-variant:small-caps;">Potvin, J.</span> (1993),
# <span>Comput. in Phys.,</span> **7**, 149.
#
# <span style="font-variant:small-caps;">Pov-Ray, Persistence of Vision
# Raytracer</span> (2013), [www.povray.org](http://www.povray.org).
#
# <span style="font-variant:small-caps;">Press, W. H., B. P. Flannery, S.
# A. Teukolsky and W. T. Vetterling</span> (1994), *Numerical Recipes*,
# Cambridge University Press, Cambridge.
#
# <span style="font-variant:small-caps;">Python for Programmers</span>
# (2014), <https://wiki.python.org/moin/BeginnersGuide/Programmers>.
#
# <span style="font-variant:small-caps;">LearnPython.org Interactive
# Python Tutorial</span> (2014), <http://www.learnpython.org/>.
#
# <span style="font-variant:small-caps;">The Python Tutorial</span>
# (2014),
# [docs.python.org/2/tutorial/](http://docs.python.org/2/tutorial/).
#
# <span style="font-variant:small-caps;">Python Index of Packages</span>
# (2014), [pypi.python.org/pypi](https://pypi.python.org/pypi).
#
# <span style="font-variant:small-caps;">Python Documentation</span>
# (2014), [www.python.org/doc](http://www.python.org/doc/).
#
# <span style="font-variant:small-caps;">Quinn, M. J.</span> (2004),
# *Parallel Programming in C with MPI and OpenMP*, McGraw Hill, New York.
#
# <span style="font-variant:small-caps;">Ramasubramanian, K., and M. S.
# Sriram</span> (2000), *A comparative study of computation of Lyapunov
# spectra with different algorithms*, Physica D, **139**, 72.
#
# <span style="font-variant:small-caps;">Rapaport, D.C.</span> (1995),
# *The Art of Molecular Dynamics Simulation*, Cambridge University Press,
# Cambridge.
#
# <span style="font-variant:small-caps;">Rasband, S. N.</span> (1990),
# *Chaotic Dynamics of Nonlinear Systems*, Wiley, New York.
#
# <span style="font-variant:small-caps;">Rawitscher, G., I. Koltracht, H.
# Dai and C. Ribetti</span> (1996), <span>Comput. in Phys.</span>, **10**,
# 335.
#
# <span style="font-variant:small-caps;">Reddy, J. N.</span> (1993), *An
# Introduction to the Finite Element Method*, 2nd Ed., McGraw Hill, New
# York.
#
# <span style="font-variant:small-caps;">Refson, K.</span> (2000), *Moldy,
# A General-Purpose Molecular Dynamics Simulation Program*,
# [cc-ipcp.icp.ac.ru/\
# Moldy$\_2\_16$.html](http://http://cc-ipcp.icp.ac.ru/Moldy_2_16.html).
#
# <span style="font-variant:small-caps;">Reynolds, O.</span> (1883),
# <span>Proc. R. Soc. London</span>, **35**, 84.
#
# <span style="font-variant:small-caps;">Richardson. L. F.</span> (1961),
# *Problem of contiguity: an appendix of statistics of deadly quarrels,*
# General Systems Yearbook, **6**, 139.
#
# <span style="font-variant:small-caps;">Rowe, A. C. H., and P. C.
# Abbott</span> (1995), *Daubechies Wavelets and Mathematica*, Comput. in
# Phys., **9**, 635.
#
# <span style="font-variant:small-caps;">Russell, J. S.</span> (1844),
# *Report of the 14th Meeting of the British Association for the
# Advancement of Science*, John Murray, London.
#
# <span style="font-variant:small-caps;">Sander, E., L. M. Sander and R.
# M. Ziff</span> (1994), <span>Comput. in Phys.,</span> **8**, 420.
#
# <span style="font-variant:small-caps;">Sanders, J., and E.
# Kandrot</span> (2011), *Cuda by Example*, Addison Wesley, Upper Saddle
# River.
#
# <span style="font-variant:small-caps;">Satoh, A.</span> (2011),
# *Introduction to Practice of Molecular Simulation*, Elsevier, Amsterdam.
#
# <span style="font-variant:small-caps;">Scheck, F.</span> (1994),
# *Mechanics, from Newton’s Laws to Deterministic Chaos*, 2nd Ed.,
# Springer, New York.
#
# <span style="font-variant:small-caps;">Shannon, C. E.</span> (1948), *A
# Mathematical Theory of Communication*, <span>The Bell System Technical
# Journal,</span> **27,** 379.
#
# <span style="font-variant:small-caps;">SciPy, a Python-based
# ecosystem</span> (2014), [www.scipy.org](http://www.scipy.org).
#
# <span style="font-variant:small-caps;">Shaw C. T.</span> (1992), *Using
# Computational Fluid Dynamics*, Prentice Hall, Englewood Cliffs.
#
# <span style="font-variant:small-caps;">Singh, P. P., and W. J.
# Thompson</span> (1993), Comput. in Phys. **7**, 388.
#
# <span style="font-variant:small-caps;">Sipper., M.</span> (1997),
# *Evolution of Parallel Cellular Machines*, Springer, Heidelberg,
# [cell-auto.com](http://cell-auto.com/).
#
# <span style="font-variant:small-caps;">Smith, D. N.</span> (1991),
# *Concepts of Object-Oriented Programming*, McGraw-Hill, New York.
#
# <span style="font-variant:small-caps;">Smith, S. W.</span> (1999), *The
# Scientist and Engineer’s Guide to Digital Signal Processing*, California
# Technical Publishing, San Diego.
#
# <span style="font-variant:small-caps;">Stetz, A., J. Carroll, N.
# Chirapatpimol, M. Dixit, G. Igo, M. Nasser, D. Ortendahl and V.
# Perez-Mendez</span> (1973), *Determination of the Axial Vector Form
# Factor in the Radiative Decay of the Pion*, LBL 1707.
#
# <span style="font-variant:small-caps;">Sullivan, D.</span> (2000),
# *Electromagnetic Simulations Using the FDTD Methods*, IEEE Press, New
# York.
#
# <span style="font-variant:small-caps;">Tabor, M.</span> (1989), *Chaos
# and Integrability in Nonlinear Dynamics*, Wiley, New York.
#
# <span style="font-variant:small-caps;">Taflove, A., and S.
# Hagness</span> (2000), *Computational Electrodynamics: The Finite
# Difference Time Domain Method*, 2nd Ed., Artech House, Boston.
#
# <span style="font-variant:small-caps;">Tait, R. N., T. Smy and M. J.
# Brett</span> (1990), <span>Thin Solid Films,</span> **187**, 375.
#
# <span style="font-variant:small-caps;">Thijssen J. M.</span> (1999),
# *Computational Physics*, Cambridge University Press, Cambridge.
#
# <span style="font-variant:small-caps;">Thompson, W. J.</span> (1992),
# *Computing for Scientists and Engineers*, Wiley, New York.
#
# <span style="font-variant:small-caps;">Tickner, J.</span> (2004),
# *Simulating nuclear particle transport in stochastic media using Perlin
# noise functions*, Nucl. Instru. & Mtds, B, **203**, 124.
#
# <span style="font-variant:small-caps;">Vallée, O.</span> (2000),
# *Comment on a quantum bouncing ball*, Am J. Phys., **68**, 672.
#
# <span style="font-variant:small-caps;">van de Velde, E. F.</span>
# (1994), *Concurrent Scientific Computing*, Springer, New York.
#
# <span style="font-variant:small-caps;">van den Berg, J. C.,
# (Eds.)</span> (1999), *Wavelets in Physics*, Cambridge University Press,
# Cambridge.
#
# <span style="font-variant:small-caps;">Vano, J. A., J. C. Wildenberg, M.
# B. Anderson, J. K. Noel and J. C. Sprott</span> (2006), *Chaos in
# Low-Dimensional Lotka-Volterra Models of Competition*, Nonlinearity
# **19**, 2391–2404.
#
# <span style="font-variant:small-caps;">Visscher, P. B.</span> (1991),
# <span>Comput. in Phys.,</span> **5**, 596.
#
# <span style="font-variant:small-caps;">Vold, M. J.</span> (1959),
# <span>J. Collod. Sci.,</span> **14**, 168.
#
# <span style="font-variant:small-caps;">Volterra, V.</span> (1926),
# *Variazioni e fluttuazioni del numero d’individui in specie animali
# conviventi*, Mem. R. Accad. Naz. dei Lincei. Ser. VI, **2**.
#
# <span style="font-variant:small-caps;">Warburton, R. D. H., and J.
# Wang</span> (2004), *Analysis of asymptotic projectile motion with air
# resistance using the Lambert W. function*, Am. J. Phys., **72**, 1404.
#
# <span style="font-variant:small-caps;">Ward, D. W., and K. A.
# Nelson</span> (2005), *Finite Difference Time Domain, FDTD, Simulations
# of Electromagnetic Wave Propagation using a Spreadsheet*, Computer Apps.
# in Engr. Education, 13, No 3, 213-221.
#
# <span style="font-variant:small-caps;">Whineray, J.</span> (1992), *An
# energy representation approach to the quantum bouncer*, Am. J. Phys.,
# **60**, 948.
#
# <span style="font-variant:small-caps;">Williams, G. P.</span> (1997),
# *Chaos Theory Tamed*, Joseph Henry Press, Washington.
#
# <span style="font-variant:small-caps;">Witten, T. A., and L. M.
# Sander</span> (1981), <span>Phys. Rev. Lett.,</span> **47**, 1400;
# (1983), Phys. Rev., **B 27**, 5686.
#
# <span style="font-variant:small-caps;">Wolf, A., J. B. Swift, H. L.
# Swinney and J. A. Vastano</span> (1985), *Determining Lyapunov Exponents
# from a Time Series*, Physica D, **16**, 285.
#
# <span style="font-variant:small-caps;">Wolfram S.</span> (1983),
# *Statistical Mechanics of Cellular Automata*, Rev. Mod. Phys., **55**,
# 601.
#
# <span style="font-variant:small-caps;">Yang, C. N.</span> (1952), *The
# Spontaneous Magnetization of a Two-Dimensional Ising Model,* Phys. Rev.,
# **85**, 809.
#
# <span style="font-variant:small-caps;">Yee, K.</span> (1966),  IEEE
# Transactions on Antennas and Propagation, **AP-14**, 302.
#
# <span style="font-variant:small-caps;">Yue, K., K. M. Fiebig, P. D.
# Thomas, H. S. Chan, E. I. Shakhnovich and A. Dill</span> (1995), Proc.
# Natl. Acad. Sci. USA, **92**, 325.
#
# <span style="font-variant:small-caps;">Zabusky, N. J., and M. D.
# Kruskal</span> (1965), Phys. Rev. Lett., **15**, 240.
#
# <span style="font-variant:small-caps;">Zeller, C.</span> (2008), *High
# Performance Computing with CUDA*, [www.nvidia.com/object/\
# sc10$\_$cuda$\_$tutorial.htmlP](http://www.nvidia.com/object/sc10_cuda_tutorial.html).
