# %%
import pandas as pd

df = pd.read_csv("smoking_death.csv")
df[:4]
# Out:
#    age  smoke_cigars_pipe  smoke_both  smoke_cigarettes  population  deaths
# 0    1                  0           0                 0         656      18
# 1    2                  0           0                 0         359      22
# 2    3                  0           0                 0         249      19
# 3    4                  0           0                 0         632      55

# %%
grouped1 = df.groupby(['smoke_cigars_pipe','smoke_both','smoke_cigarettes']).sum()
grouped1[['population','deaths']]
# Out:
#                                                population  deaths
# smoke_cigars_pipe smoke_both smoke_cigarettes
# 0                 0          0                       5163     820
#                              1                      18726    3141
#                   1          0                      27691    4128
# 1                 0          0                       4542    1041

# %%
grouped2 = df.groupby(['smoke_cigars_pipe','smoke_both','smoke_cigarettes']).mean()
grouped2[['population','deaths']]
# Out:
#                                                 population      deaths
# smoke_cigars_pipe smoke_both smoke_cigarettes
# 0                 0          0                  573.666667   91.111111
#                              1                 2080.666667  349.000000
#                   1          0                 3076.777778  458.666667
# 1                 0          0                  504.666667  115.666667

# %%
grouped1['rate'] = grouped1['deaths']/grouped1['population']

# %%
grouped1[['population','deaths','rate']]
# Out:
#                                                population  deaths      rate
# smoke_cigars_pipe smoke_both smoke_cigarettes
# 0                 0          0                       5163     820  0.158822
#                              1                      18726    3141  0.167735
#                   1          0                      27691    4128  0.149074
# 1                 0          0                       4542    1041  0.229194

# %%
grouped3 = df.groupby('age').sum()
grouped3[['population','deaths']]
# Out:
#      population  deaths
# age
# 1          8742     293
# 2          5732     335
# 3          4465     402
# 4          8956    1183
# 5         11756    2009
# 6          8147    1933
# 7          4720    1436
# 8          2335     914
# 9          1269     625

# %%
df['pct'] = df['deaths']*1. / df['population']*1.
df[:4]
# Out:
#    age  smoke_cigars_pipe  smoke_both  smoke_cigarettes  population  deaths       pct
# 0    1                  0           0                 0         656      18  0.027439
# 1    2                  0           0                 0         359      22  0.061281
# 2    3                  0           0                 0         249      19  0.076305
# 3    4                  0           0                 0         632      55  0.087025

# %%
pivot = df.pivot_table('pct',cols=['smoke_cigars_pipe','smoke_both','smoke_cigarettes'],
                       rows='age')
pivot.columns
# Out:
# MultiIndex
# [(0, 0, 0), (0, 0, 1), (0, 1, 0), (1, 0, 0)]

# %%
plt.plot(pivot)
plt.legend(['icmiyor','puro','ikisi de','puro ve pipo'],loc="best")
plt.show()
