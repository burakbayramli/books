# %%
from demo_support import *
import statsmodels.api as sm
import statsmodels.tsa.api as tsa

# %% [markdown]
# Ordinary least squares
# ======================

# %%
data = sm.datasets.stackloss.load()
X = DataFrame(data.exog, columns=data.exog_name)
X['intercept'] = 1.
Y = Series(data.endog)

model = sm.OLS(Y, X)
results = model.fit()
print results.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.898
# Method:                 Least Squares   F-statistic:                     59.90
# Date:                Sat, 09 Mar 2013   Prob (F-statistic):           3.02e-09
# Time:                        23:07:01   Log-Likelihood:                -52.288
# No. Observations:                  21   AIC:                             112.6
# Df Residuals:                      17   BIC:                             116.8
# Df Model:                           3
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# AIRFLOW        0.7156      0.135      5.307      0.000         0.431     1.000
# WATERTEMP      1.2953      0.368      3.520      0.003         0.519     2.072
# ACIDCONC      -0.1521      0.156     -0.973      0.344        -0.482     0.178
# intercept    -39.9197     11.896     -3.356      0.004       -65.018   -14.821
# ==============================================================================
# Omnibus:                        0.713   Durbin-Watson:                   1.485
# Prob(Omnibus):                  0.700   Jarque-Bera (JB):                0.140
# Skew:                          -0.193   Prob(JB):                        0.932
# Kurtosis:                       3.107   Cond. No.                     1.81e+03
# ==============================================================================
#
# The condition number is large, 1.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
results.params
# Out:
# AIRFLOW       0.715640
# WATERTEMP     1.295286
# ACIDCONC     -0.152123
# intercept   -39.919674

# %%
results.cov_params()
# Out:
#             AIRFLOW  WATERTEMP  ACIDCONC   intercept
# AIRFLOW    0.018187  -0.036511 -0.007144    0.287587
# WATERTEMP -0.036511   0.135442  0.000010   -0.651794
# ACIDCONC  -0.007144   0.000010  0.024428   -1.676321
# intercept  0.287587  -0.651794 -1.676321  141.514741

# %% [markdown]
# Robust linear model (RLM)
# =========================

# %%
huber_t = sm.RLM(Y, X, M=sm.robust.norms.HuberT())
hub_results = huber_t.fit()
hub_results.params
# Out:
# AIRFLOW       0.829384
# WATERTEMP     0.926066
# ACIDCONC     -0.127847
# intercept   -41.026498

# %%
hub_results.bse
# Out:
# AIRFLOW      0.111005
# WATERTEMP    0.302930
# ACIDCONC     0.128650
# intercept    9.791899

# %%
hub_results.bcov_scaled
# Out:
#             AIRFLOW  WATERTEMP  ACIDCONC  intercept
# AIRFLOW    0.012322  -0.024737 -0.004840   0.194851
# WATERTEMP -0.024737   0.091767  0.000007  -0.441614
# ACIDCONC  -0.004840   0.000007  0.016551  -1.135767
# intercept  0.194851  -0.441614 -1.135767  95.881277

# %% [markdown]
# Time series analysis
# ====================

# %%
data = sm.datasets.macrodata.load()
mdata = data.data

df = DataFrame.from_records(mdata)
quarter_end = datetools.BQuarterEnd()
df.index = [quarter_end.rollforward(datetime(int(y), int(q) * 3, 1))
            for y, q in zip(df.pop('year'), df.pop('quarter'))]
logged = np.log(df.ix[:, ['m1', 'realgdp', 'cpi']])
logged.plot(subplots=True)
# Out:
# array([Axes(0.125,0.725;0.775x0.175), Axes(0.125,0.4625;0.775x0.175),
#        Axes(0.125,0.2;0.775x0.175)], dtype=object)

# %%
log_difference = logged.diff().dropna()
plot_acf_multiple(log_difference.values)

# %% [markdown]
# Vector Autoregressive (VAR) Process
# ===================================

# %%
model = tsa.VAR(log_difference)
model.select_order()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-42a372de5689> in <module>()
# ----> 1 model = tsa.VAR(log_difference)
#       2 model.select_order()
#
# /usr/local/lib/python2.7/dist-packages/statsmodels-0.5.0-py2.7-linux-i686.egg/statsmodels/tsa/vector_ar/var_model.pyc in __init__(self, endog, dates, names, freq)
#     334     """
#     335     def __init__(self, endog, dates=None, names=None, freq=None):
# --> 336         super(VAR, self).__init__(endog, None, dates, freq)
#     337         if names is not None:
#     338             import warnings
#
# /usr/local/lib/python2.7/dist-packages/statsmodels-0.5.0-py2.7-linux-i686.egg/statsmodels/tsa/base/tsa_model.pyc in __init__(self, endog, exog, dates, freq)
#      46     def __init__(self, endog, exog=None, dates=None, freq=None):
#      47         super(TimeSeriesModel, self).__init__(endog, exog)
# ---> 48         self._init_dates(dates, freq)
#      49
#      50     def _init_dates(self, dates, freq):
#
# /usr/local/lib/python2.7/dist-packages/statsmodels-0.5.0-py2.7-linux-i686.egg/statsmodels/tsa/base/tsa_model.pyc in _init_dates(self, dates, freq)
#      73             dates = Index(dates)
#      74         self._data.dates = dates
# ---> 75         self._data.freq = _check_freq(freq) #TODO: drop if can get info from dates
#      76         #TODO: still gonna need some more sophisticated handling here
#      77
#
# /usr/local/lib/python2.7/dist-packages/statsmodels-0.5.0-py2.7-linux-i686.egg/statsmodels/tsa/base/tsa_model.pyc in _check_freq(freq)
#      14 def _check_freq(freq):
#      15     if freq and freq not in _freqs:
# ---> 16         raise ValueError("freq %s not understood" % freq)
#      17     return freq
#      18
#
# ValueError: freq BQ-DEC not understood

# %%
res = model.fit(2)
res.summary()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-fe57b9a8a0f8> in <module>()
# ----> 1 res = model.fit(2)
#       2 res.summary()
#
# /usr/local/lib/python2.7/dist-packages/statsmodels-0.5.0-py2.7-linux-i686.egg/statsmodels/regression/linear_model.pyc in fit(self, method, **kwargs)
#     249             # no upper triangular solve routine in numpy/scipy?
#     250         if isinstance(self, OLS):
# --> 251             lfit = OLSResults(self, beta,
#     252                        normalized_cov_params=self.normalized_cov_params)
#     253         else:
#
# UnboundLocalError: local variable 'beta' referenced before assignment

# %%
res.is_stable()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5381a054ed6e> in <module>()
# ----> 1 res.is_stable()
#
# NameError: name 'res' is not defined

# %%
# impulse response function
irf = res.irf(20)
irf.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b473d990ea7a> in <module>()
#       1 # impulse response function
# ----> 2 irf = res.irf(20)
#       3 irf.plot()
#
# NameError: name 'res' is not defined

# %%
# Forecast error variance decomposition
fevd = res.fevd()
fevd.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4def1010f0a2> in <module>()
#       1 # Forecast error variance decomposition
# ----> 2 fevd = res.fevd()
#       3 fevd.plot()
#
# NameError: name 'res' is not defined

# %%
res.test_whiteness()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-cad1166ee8e4> in <module>()
# ----> 1 res.test_whiteness()
#
# NameError: name 'res' is not defined

# %%
res.test_causality('m1', 'realgdp')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-970af54ca18c> in <module>()
# ----> 1 res.test_causality('m1', 'realgdp')
#
# NameError: name 'res' is not defined

# %%
res.test_normality()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b73a1376995a> in <module>()
# ----> 1 res.test_normality()
#
# NameError: name 'res' is not defined

# %% [markdown]
# Autoregressive-Moving Average (ARMA) Process
# ============================================

# %%
import numpy as np
import statsmodels.api as sm

# Generate some data from an ARMA process
from statsmodels.tsa.arima_process import arma_generate_sample

arparams = np.array([.75, -.25])
maparams = np.array([.65, .35])

# The conventions of the arma_generate function require that we specify a
# 1 for the zero-lag of the AR and MA parameters and that the AR parameters
# be negated.
arparams = np.r_[1, -arparams]
maparam = np.r_[1, maparams]
nobs = 250
y = arma_generate_sample(arparams, maparams, nobs)
plot(y)

# %%
# Now, optionally, we can add some dates information. For this example,
# we'll use a pandas time series.
import pandas
dates = sm.tsa.datetools.dates_from_range('1980m1', length=nobs)
y = pandas.Series(y, index=dates)
arma_mod = sm.tsa.ARMA(y, freq='M')
arma_res = arma_mod.fit(order=(2,2), trend='nc', disp=-1)
arma_res.params
# Out:
# /usr/local/lib/python2.7/dist-packages/statsmodels-0.5.0-py2.7-linux-i686.egg/statsmodels/tsa/arima_model.py:226: FutureWarning: In the next release order will not be optional in the model constructor.
#   "in the model constructor.", FutureWarning)
# /usr/local/lib/python2.7/dist-packages/statsmodels-0.5.0-py2.7-linux-i686.egg/statsmodels/tsa/arima_model.py:657: FutureWarning: The order argument to fit is deprecated. Please use the model constructor argument order. This will overwrite any order given in the model constructor.
#   "constructor.", FutureWarning)
# ar.L1.y    1.128868
# ar.L2.y   -0.463882
# ma.L1.y    0.153266
# ma.L2.y   -0.201761

# %% [markdown]
# Teaser: Formulas
# ================

# %%
from formula.terms import fromrec
from formula.ancova import *

df = read_table('epigen.dat', index_col=None)
recs = df.to_records(index=False)

terms = fromrec(recs)
race = terms['race']
edu = terms['edu']
smoke = terms['smoke']
ancova = ANCOVA(race, edu, (1, (race, edu)))
formula = ancova.formula + smoke

df.head().T
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-648f0f55ef8a> in <module>()
# ----> 1 from formula.terms import fromrec
#       2 from formula.ancova import *
#       3
#       4 df = read_table('epigen.dat', index_col=None)
#       5 recs = df.to_records(index=False)
#
# ImportError: No module named formula.terms

# %%
design = DataFrame.from_records(formula.design(recs))
print sm.OLS(recs['methyl1'],
             design).fit().summary()
# Out:
#      Summary of Regression Results
# =======================================
# | Dependent Variable:            [&apos;y&apos;]|
# | Model:                           OLS|
# | Method:                Least Squares|
# | Date:               Wed, 14 Sep 2011|
# | Time:                       16:54:35|
# | # obs:                         314.0|
# | Df residuals:                  304.0|
# | Df model:                        9.0|
# ========================================================================================
# |                             coefficient     std. error    t-statistic          prob. |
# ----------------------------------------------------------------------------------------
# | 1                                 46.64          1.465        31.8392         0.0000 |
# | edu_ltCollege*race_EA            -3.250          2.317        -1.4024         0.1618 |
# | edu_ltCollege*race_Other       -0.09743          3.739        -0.0261         0.9792 |
# | edu_ltHS*race_EA                0.08199          2.202         0.0372         0.9703 |
# | edu_ltHS*race_Other               1.542          3.448         0.4472         0.6550 |
# | edu_ltCollege                     1.326          1.715         0.7734         0.4399 |
# | edu_ltHS                        -0.1423          1.648        -0.0864         0.9312 |
# | race_EA                          0.7005          1.627         0.4305         0.6671 |
# | race_Other                       0.6537          2.455         0.2662         0.7902 |
# | smoke                             3.079          1.033         2.9821         0.0031 |
# ========================================================================================
# |                          Models stats                      Residual stats  |
# ------------------------------------------------------------------------------
# | R-squared:                    0.03826   Durbin-Watson:              1.206  |
# | Adjusted R-squared:          0.009784   Omnibus:                    42.88  |
# | F-statistic:                    1.344   Prob(Omnibus):          4.876e-10  |
# | Prob (F-statistic):            0.2137   JB:                         29.20  |
# | Log likelihood:                -1030.   Prob(JB):               4.556e-07  |
# | AIC criterion:                  2080.   Skew:                      0.7494  |
# | BIC criterion:                  2117.   Kurtosis:                   4.991  |
# ------------------------------------------------------------------------------
