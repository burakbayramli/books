# %% [markdown]
# # for_loop.ipynb
# Use a for loop to generate multiple solutions to the quadratic equation, $a x^2 + b x + c = 0$.

# %%
import numpy as np

b, c = 2, -1
for a in np.arange(-1, 2, 0.3):
	x = (-b + np.sqrt(b**2 - 4*a*c)) / (2*a)
	print("a= {:.4f}, x= {:.4f}".format(a,x))
# Out:
# a= -1.0000, x= 1.0000
# a= -0.7000, x= 0.6461
# a= -0.4000, x= 0.5635
# a= -0.1000, x= 0.5132
# a= 0.2000, x= 0.4772
# a= 0.5000, x= 0.4495
# a= 0.8000, x= 0.4271
# a= 1.1000, x= 0.4083
# a= 1.4000, x= 0.3923
# a= 1.7000, x= 0.3783
