# %%
# %matplotlib inline

# %%
from pandasql import sqldf
from pandasql import load_meat, load_births

# i installed pandasql with: pip install -U pandasql
meat = load_meat()
births = load_births()
 
print meat.head()
# Out:
#                  date  beef  veal  pork  lamb_and_mutton  broilers  \
# 0 1944-01-01 00:00:00   751    85  1280               89       NaN
# 1 1944-02-01 00:00:00   713    77  1169               72       NaN
# 2 1944-03-01 00:00:00   741    90  1128               75       NaN
# 3 1944-04-01 00:00:00   650    89   978               66       NaN
# 4 1944-05-01 00:00:00   681   106  1029               78       NaN
#
#    other_chicken  turkey
# 0            NaN     NaN
# 1            NaN     NaN
# 2            NaN     NaN
# 3            NaN     NaN
# 4            NaN     NaN

# %%
print births.head()
# Out:
#                  date  births
# 0 1975-01-01 00:00:00  265775
# 1 1975-02-01 00:00:00  241045
# 2 1975-03-01 00:00:00  268849
# 3 1975-04-01 00:00:00  247455
# 4 1975-05-01 00:00:00  254545

# %%
import matplotlib.pyplot as plt
from pandasql import *
import pandas as pd
 
pysqldf = lambda q: sqldf(q, globals())
 
q  = """
SELECT
  m.date
  , m.beef
  , b.births
FROM
  meat m
LEFT JOIN
  births b
    ON m.date = b.date
WHERE
    m.date > '1974-12-31';
"""
 
meat = load_meat()
births = load_births()
 
df = pysqldf(q)
df.births = df.births.fillna(method='backfill')
 
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(pd.rolling_mean(df['beef'], 12), color='b')
ax1.set_xlabel('months since 1975')
ax1.set_ylabel('cattle slaughtered', color='b')
 
ax2 = ax1.twinx()
ax2.plot(pd.rolling_mean(df['births'], 12), color='r')
ax2.set_ylabel('babies born', color='r')
plt.title("Beef Consumption and the Birth Rate")
plt.show()

# %%
q = """
    SELECT
        *
    FROM
        meat
    LIMIT 10;"""
 
print sqldf(q, locals())
# Out:
#                  date  beef  veal  pork  lamb_and_mutton broilers  \
# 0 1944-01-01 00:00:00   751    85  1280               89     None
# 1 1944-02-01 00:00:00   713    77  1169               72     None
# 2 1944-03-01 00:00:00   741    90  1128               75     None
# 3 1944-04-01 00:00:00   650    89   978               66     None
# 4 1944-05-01 00:00:00   681   106  1029               78     None
# 5 1944-06-01 00:00:00   658   125   962               79     None
# 6 1944-07-01 00:00:00   662   142   796               82     None
# 7 1944-08-01 00:00:00   787   175   748               87     None
# 8 1944-09-01 00:00:00   774   182   678               91     None
# 9 1944-10-01 00:00:00   834   215   777              100     None
#
#   other_chicken turkey
# 0          None   None
# 1          None   None
# 2          None   None
# 3          None   None
# 4          None   None
# 5          None   None
# 6          None   None
# 7          None   None
# 8          None   None
# 9          None   None

# %%
# births per year
q = """ 
    SELECT
        strftime("%Y", date)
        , SUM(births)
    FROM births
    GROUP BY 1
    ORDER BY 1; 
"""
 
print sqldf(q, locals())
# Out:
#    strftime("%Y", date)  SUM(births)
# 0                  1975      3136965
# 1                  1976      6304156
# 2                  1979      3333279
# 3                  1982      3612258
# 4                  1983      7333238
# 5                  1986      7308074
# 6                  1987      3760561
# 7                  1988      3756547
# 8                  1990      7718904
# 9                  1991     11714356
# 10                 1993      8194907
# 11                 1995      4000240
# 12                 1996      3952767
# 13                 1997      3899589
# 14                 1998      3891494
# 15                 1999      3880894
# 16                 2000      3941553
# 17                 2001      8018231
# 18                 2002      4025933
# 19                 2003      4021726
# 20                 2005      8210950
# 21                 2007      4138349
# 22                 2008      4265555
# 23                 2011      4247694
# 24                 2012      4130665

# %%
def pysqldf(q):
    return sqldf(q, globals())
    
q = """
    SELECT
        *
    FROM
        births
    LIMIT 10;"""
 
print pysqldf(q)
# Out:
#                  date  births
# 0 1975-01-01 00:00:00  265775
# 1 1975-02-01 00:00:00  241045
# 2 1975-03-01 00:00:00  268849
# 3 1975-04-01 00:00:00  247455
# 4 1975-05-01 00:00:00  254545
# 5 1975-06-01 00:00:00  254096
# 6 1975-07-01 00:00:00  275163
# 7 1975-08-01 00:00:00  281300
# 8 1975-09-01 00:00:00  270738
# 9 1975-10-01 00:00:00  265494

# %%
# joining meats + births on date
q = """
    SELECT
        m.date
        , b.births
        , m.beef
    FROM
        meat m
    INNER JOIN
        births b
            on m.date = b.date
    ORDER BY
        m.date
    LIMIT 100;
    """
 
joined = pysqldf(q)
print joined.head()
# Out:
#                  date  births  beef
# 0 1975-01-01 00:00:00  265775  2106
# 1 1975-02-01 00:00:00  241045  1845
# 2 1975-03-01 00:00:00  268849  1891
# 3 1975-04-01 00:00:00  247455  1895
# 4 1975-05-01 00:00:00  254545  1849

# %%
q = """
    SELECT
        date
        , beef
        , veal
        , pork
        , lamb_and_mutton
    FROM
        meat
    WHERE
        lamb_and_mutton >= veal
    ORDER BY date DESC
    LIMIT 10;
    """
 
print pysqldf(q)
# Out:
#                  date    beef  veal    pork  lamb_and_mutton
# 0 2012-11-01 00:00:00  2206.6  10.1  2078.7             12.4
# 1 2012-10-01 00:00:00  2343.7  10.3  2210.4             14.2
# 2 2012-09-01 00:00:00  2016.0   8.8  1911.0             12.5
# 3 2012-08-01 00:00:00  2367.5  10.1  1997.9             14.2
# 4 2012-07-01 00:00:00  2200.8   9.5  1721.8             12.5
# 5 2012-06-01 00:00:00  2252.1   8.9  1750.4             12.4
# 6 2012-05-01 00:00:00  2232.0  10.4  1926.8             13.6
# 7 2012-04-01 00:00:00  1990.6   9.9  1841.7             12.9
# 8 2012-03-01 00:00:00  2159.8  10.0  1987.9             14.2
# 9 2012-02-01 00:00:00  2009.0   9.8  1882.9             12.3

# %%
q = """SELECT 
    *
    FROM
        meat
    ORDER BY RANDOM()
    LIMIT 10;"""
print pysqldf(q)
# Out:
#                  date  beef  veal  pork  lamb_and_mutton  broilers  \
# 0 1965-09-01 00:00:00  1624    90   917               59     469.8
# 1 1987-12-01 00:00:00  1924    36  1390               28    1336.8
# 2 1978-03-01 00:00:00  2074    60  1179               28     830.0
# 3 1997-02-01 00:00:00  1919    27  1309               21    2097.8
# 4 1954-04-01 00:00:00   988   111   661               58       NaN
# 5 2000-07-01 00:00:00  2202    18  1409               16    2417.7
# 6 1984-08-01 00:00:00  2112    44  1175               31    1210.5
# 7 1988-06-01 00:00:00  2025    34  1233               27    1398.0
# 8 1961-09-01 00:00:00  1267    85   838               67     373.0
# 9 1971-03-01 00:00:00  1866    48  1333               51     616.5
#
#   other_chicken  turkey
# 0          None   224.4
# 1          None   297.0
# 2          None    86.3
# 3          None   391.7
# 4          None     NaN
# 5          None   425.9
# 6          None   279.6
# 7          None   373.2
# 8          None   179.4
# 9          None    42.7

# %%
#################################################
# UNION ALL
#################################################
q = """
        SELECT
            date
            , 'beef' AS meat_type
            , beef AS value
        FROM meat
 
        UNION ALL
 
        SELECT
            date
            , 'veal' AS meat_type
            , veal AS value
        FROM meat
        
        UNION ALL
        
        SELECT
            date
            , 'pork' AS meat_type
            , pork AS value
        FROM meat
 
        UNION ALL
 
        SELECT
            date
            , 'lamb_and_mutton' AS meat_type
            , lamb_and_mutton AS value
        FROM meat
 
        ORDER BY 1
    """
print pysqldf(q).head(20)
# Out:
#                    date        meat_type  value
# 0   1944-01-01 00:00:00             beef    751
# 1   1944-01-01 00:00:00             veal     85
# 2   1944-01-01 00:00:00             pork   1280
# 3   1944-01-01 00:00:00  lamb_and_mutton     89
# 4   1944-02-01 00:00:00             beef    713
# 5   1944-02-01 00:00:00             veal     77
# 6   1944-02-01 00:00:00             pork   1169
# 7   1944-02-01 00:00:00  lamb_and_mutton     72
# 8   1944-03-01 00:00:00             beef    741
# 9   1944-03-01 00:00:00             veal     90
# 10  1944-03-01 00:00:00             pork   1128
# 11  1944-03-01 00:00:00  lamb_and_mutton     75
# 12  1944-04-01 00:00:00             beef    650
# 13  1944-04-01 00:00:00             veal     89
# 14  1944-04-01 00:00:00             pork    978
# 15  1944-04-01 00:00:00  lamb_and_mutton     66
# 16  1944-05-01 00:00:00             beef    681
# 17  1944-05-01 00:00:00             veal    106
# 18  1944-05-01 00:00:00             pork   1029
# 19  1944-05-01 00:00:00  lamb_and_mutton     78

# %%
#################################################
# subqueries
# fancy!
#################################################
q = """
    SELECT 
        m1.date
        , m1.beef 
    FROM 
        meat m1 
    WHERE m1.date IN 
        (SELECT 
            date 
        FROM meat 
        WHERE 
            beef >= broilers 
        ORDER BY date)
"""
 
more_beef_than_broilers = pysqldf(q)
print more_beef_than_broilers.head(10)
# Out:
#                  date  beef
# 0 1960-01-01 00:00:00  1196
# 1 1960-02-01 00:00:00  1089
# 2 1960-03-01 00:00:00  1201
# 3 1960-04-01 00:00:00  1066
# 4 1960-05-01 00:00:00  1202
# 5 1960-06-01 00:00:00  1247
# 6 1960-07-01 00:00:00  1166
# 7 1960-08-01 00:00:00  1307
# 8 1960-09-01 00:00:00  1298
# 9 1960-10-01 00:00:00  1263
